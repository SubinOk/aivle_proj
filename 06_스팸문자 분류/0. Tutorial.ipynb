# %% [markdown]
# # 안녕하세요^^
# # AIVLE 미니 프로젝트에 오신 여러분을 환영합니다.
# * 본 과정에서는 실제 사례와 데이터를 기반으로 문제를 해결하는 전체 과정을 자기 주도형 실습으로 진행해볼 예정입니다.
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %% [markdown]
# ### References
# > * 한국어 처리
# >> * [konlpy - 한국어 처리 라이브러리](https://konlpy.org/ko/latest/)
# >> * [한국어 품사 태그 비교표](https://docs.google.com/spreadsheets/d/1OGAjUvalBuX-oZvZ_-9tEfYD2gQe7hTGsgUpiiBSXI8/edit#gid=0)
# >> * [한국어 품사 태깅 성능 비교](https://konlpy.org/ko/latest/morph/#comparison-between-pos-tagging-classes)
# >> * [한국어 시스템 사전](https://konlpy.org/ko/latest/data/#corpora)
#
# > * 자연어 처리
# >> * [NLTK](https://www.nltk.org/book/)
# >> * [gensim](https://radimrehurek.com/gensim/)
# >> * [Google guide](https://developers.google.com/machine-learning/guides/text-classification/step-2)
# >> * [WordCloud](https://amueller.github.io/word_cloud/)

# %% [markdown]
# # 시작 이전에 맛보기 실습을 해볼게요.

# %%
# 필요 라이브러리부터 설치할께요.
# !pip install konlpy pandas seaborn gensim wordcloud mecab-ko

# %%
## import sklearn
import pandas as pd
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import tensorflow as tf
fm.findSystemFonts()
plt.rcParams['font.family']= ["Malgun Gothic"]
plt.rcParams["axes.unicode_minus"]=False

# GPU 환경 설정하기
# assert tf.test.is_gpu_available() == True, 'GPU 설정을 확인하세요.'
print(tf.config.list_physical_devices('GPU'))
print(tf.config.list_logical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Tutorial data - 대한민국 헌법

# %%
import nltk
from eunjeon import Mecab
from konlpy.corpus import kolaw
constitution = kolaw.open('constitution.txt').read()
mecab = Mecab()

# %% [markdown]
# ### 1. tokenization
# #### 1-1. 형태소 추출

# %%
# mecab을 이용해 문장을 명사단위로 토큰화 합니다.
# nouns 함수를 이용합니다.
# mecab 이용시 한글의 경우 띄어쓰기를 하지 않아도 추출이 가능합니다. 
morphs_constitution = mecab.morphs(constitution)
print(len(morphs_constitution))
morphs_constitution[:10]
# Out:
# 9286
# ['대한민국', '헌법', '유구', '한', '역사', '와', '전통', '에', '빛나', '는']

# %% [markdown]
# #### 1-2. 명사 추출

# %%
# 형태소 단위로 토큰화 해 봅니다.
nouns_constitution = mecab.nouns(constitution)
print(len(nouns_constitution))
nouns_constitution[:10]
# Out:
# 3610
# ['대한민국', '헌법', '역사', '전통', '우리', '국민', '운동', '건립', '대한민국', '임시']

# %% [markdown]
# ## 2. Part Of Speech tagging(품사 태깅)

# %%
pos_constitution = mecab.pos(constitution)
print(len(pos_constitution))
print(pos_constitution[:3])
# print(mecab.pos(constitution,flatten=False)[:3])
# print(mecab.pos(constitution,join=True)[:3])
# Out:
# 9286
# [('대한민국', 'NNP'), ('헌법', 'NNG'), ('유구', 'XR')]

# %% [markdown]
# ## 3. [NLTK](https://www.nltk.org/book/)

# %%
from nltk import bigrams

# %%
nltk_morphs_constitution = nltk.Text(morphs_constitution)
nltk_nouns_constitution = nltk.Text(nouns_constitution)

# %% [markdown]
# ### 3-1. Frequency plot

# %%
plt.figure(figsize=(8,4))
plt.title("형태소 개수 : " + str(len(nltk_morphs_constitution.tokens)))
nltk_morphs_constitution.plot(10)

plt.figure(figsize=(8,4))
plt.title("명사 개수 : " + str(len(nltk_nouns_constitution.tokens)))
nltk_nouns_constitution.plot(10)

plt.show()

# %% [markdown]
# ### 3-2. Similar words

# %%
nltk_morphs_constitution.similar('국민')
# Out:
# 국회 국가 대한민국 정부 조국 법관 법원 타인 판결 근로 국회의원 대통령 대법원장 법령 농지 정치 책임 인 차 권력

# %%
nltk_nouns_constitution.similar('국민')
# Out:
# 국회 법률 대통령 대한민국 지향 이 법관 근로자 국회의원 과반수 제안

# %% [markdown]
# ### 3-3. Lexical dispersion_plot

# %%
plt.figure(figsize=(10,5))
nltk_morphs_constitution.dispersion_plot(['국회','국가','대한민국',])
plt.show()

# plt.figure(figsize=(10,5))
# nltk_nouns_constitution.dispersion_plot(['국회','국가','대한민국',])
# plt.show()

# %%
nltk_morphs_constitution.concordance('국회',width=20,lines=5)
# Out:
# Displaying 5 of 69 matches:
#  헌법 을 이제 국회 의 의결 을 거
#  . 제 3 장 국회 제 40 조 입
# 조 입법 권 은 국회 에 속한다 .
# 제 41 조 ① 국회 는 국민 의 보
# 고 는 회기 중 국회 의 동의 없이

# %%
nltk_nouns_constitution.concordance('국회',width=20,lines=5)
# Out:
# Displaying 5 of 69 matches:
#  차 개정 헌법 국회 의결 국민 투표
#  이익 처우 장 국회 조 입법 국회
#  국회 조 입법 국회 조 국회 국민
#  입법 국회 조 국회 국민 보통 평등
#  제외 회기 중 국회 동의 체포 구금

# %%
nltk_nouns_constitution.index('국회')
# Out:
# 83

# %% [markdown]
# ### 3-5. Collocation

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\master\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
nltk_morphs_constitution.collocations(window_size=5)
print("*"*50)
nltk_nouns_constitution.collocations(window_size=5)
# Out:
# 재판소 재판관; 단체교섭 단체행동권; 가진다 피고인; 대법원장 대법관; 단체행동권 가진다; 대통령 국무총리; 아니한다
# 국회의원; 국무총리 대통령; 재판관 대통령
# **************************************************
# 재판소 재판관; 단체교섭 단체행동권; 대법원장 대법관; 국회의원 선거후; 국무총리 행정각부; 대법관 대법관; 국회의원
# 국회의원; 공무원 기업체; 공무원 후임자; 대법관 대법원장; 국무총리 대통령; 대통령 국무총리; 대통령 행정각부; 재판관
# 재판관; 과반수 과반수; 대통령 당선자; 대통령 법률안; 법률안 대통령; 후임자 대통령; 재판관 대통령

# %% [markdown]
# ## 4. [WordCloud](https://amueller.github.io/word_cloud/)

# %%
type(nltk_nouns_constitution)
# Out:
# nltk.text.Text

# %%
import matplotlib.font_manager as font_manager
from wordcloud import WordCloud

NGC_path = font_manager.findfont('Malgun Gothic')
# wc = WordCloud(font_path=NGC_path,max_font_size=40).generate(constitution)
wc = WordCloud(font_path=NGC_path,max_font_size=40,background_color="white").generate(' '.join(nltk_nouns_constitution))

plt.figure(figsize=(12,6))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %% [markdown]
# ## 5. vocabulary 만들기

# %% [markdown]
# 지금부터는 단어사전을 만드는 원리에 대해 이해하는 실습을 해보도록 하겠습니다.<br>
# 아래 로직을 이해 하셨다가, 잠시 후 실습 때 직접 만들어 보시기 바랍니다.
# > 1. 단어를 토큰화 하고, 하나의 리스트 만듭니다.
# > 2. 중복된 단어는 제거하고 토큰의 출현 빈도 순으로 내림차순 정렬 합니다.
# > 3. 각 토큰에 정수를 부여하고 dictionary 생성합니다.

# %% [markdown]
# #### 5-1. pos function 응용

# %%
# 명사는 nouns라는 함수를 이용하면 쉽게 추출이 가능한데요.
# 특수기호는 형태소 분석을 한 후에 추출을 해야 합니다. 
# 특수기호까지 추출하는 함수를 만들어 보겠습니다.

def extended_extraction(text):
    pos = mecab.pos(text)
    extended_list = []
    for i in range(len(pos)):
        # 명사 : NP, NNB, NNP, NNG
        # 특수기호 : SF, SY
        if pos[i][1] in('NP','NNB','NNP','NNG','SF','SY'):
            extended_list.append(pos[i][0])
    return extended_list

# 새로 만든 함수를 이용하여 문장의 명사와 특수기호만을 추출해서 토큰화 합니다.
# 이 함수를 이용해서 나중에 dictionary를 만들때와 문자를 숫자열로 변환하는 작업을 실습 해보시기 바랍니다.
token_list = extended_extraction(constitution)
token_list[:10]
# Out:
# ['대한민국', '헌법', '역사', '전통', '우리', '국민', '운동', '건립', '대한민국', '임시']

# %% [markdown]
# #### 5-2. Count frequency and sorting

# %%
# 2. 토큰의 출현 빈도 순으로 내림차순 정렬합니다.
# 데이터 갯수를 셀 때, 유용한 collections모듈의 Counter클래스와 most_common 함수를 이용합니다.
# most_common을 이용하면 데이터 갯수가 많은 순으로 정렬된 배열이 리턴 됩니다.
# collections모듈의 Counter클래스를 import 합니다.
from collections import Counter

# Counter 클레스를 이용하여 토큰의 빈도를 계산 합니다.
vocab_collection = Counter(token_list)

# 결과를 출력해 확인합니다.
print("고유한 토큰 갯수 : ",len(vocab_collection))
# print("토큰 목록: ", vocab_collection)

# most_common 함수 이용해서 토큰을 빈도가 높은 순으로 정렬한 배열을 얻습니다.
vocab = vocab_collection.most_common(len(vocab_collection))
print("빈도순으로 정렬 :",vocab)
# Out:
# 고유한 토큰 갯수 :  859
# 빈도순으로 정렬 : [('.', 360), ('법률', 120), ('수', 88), ('대통령', 84), ('조', 78), ('①', 78), ('②', 78), ('국가', 73), ('헌법', 69), ('국민', 69), ('국회', 69), ('때', 55), ('③', 45), ('바', 37), ('필요', 31), ('위원', 30), ('기타', 26), ('법원', 25), ('보장', 24), ('국무', 24), ('정부', 23), ('사항', 23), ('이', 22), ('회의', 22), ('자유', 21), ('권리', 21), ('선거', 21), ('의원', 21), ('경제', 20), ('④', 20), ('국회의원', 20), ('의무', 19), ('직무', 19), ('국무총리', 19), ('임명', 19), ('조직', 18), ('이상', 18), ('임기', 18), ('의결', 17), ('공무원', 17), ('경우', 17), ('장', 16), ('범위', 16), ('보호', 15), ('법관', 15), ('정책', 14), ('정당', 14), ('재판소', 14), ('재적', 14), ('항의', 14), ('노력', 13), ('재판', 13), ('인', 13), ('요구', 13), ('집회', 12), ('군사', 12), ('시행', 12), ('과반수', 12), ('출석', 12), ('찬성', 12), ('자문', 12), ('대한민국', 11), ('안', 11), ('안전', 11), ('조약', 11), ('심판', 11), ('자', 11), ('⑤', 11), ('중', 11), ('처분', 11), ('단체', 11), ('동의', 11), ('탄핵', 11), ('권한', 11), ('민주', 10), ('공포', 10), ('기관', 10), ('중요', 10), ('재판관', 10), ('대법원장', 10), ('사회', 9), ('기본', 9), ('정치', 9), ('개정', 9), ('효력', 9), ('체포', 9), ('절차', 9), ('행위', 9), ('교육', 9), ('근로', 9), ('국정', 9), ('명령', 9), ('지방', 9), ('자치', 9), ('질서', 8), ('생활', 8), ('제정', 8), ('투표', 8), ('인정', 8), ('구속', 8), ('형사', 8), ('구성', 8), ('확정', 8), ('제출', 8), ('법률안', 8), ('항', 8), ('행정', 8), ('사무', 8), ('것', 7), ('수립', 7), ('유지', 7), ('이유', 7), ('제한', 7), ('공개', 7), ('선출', 7), ('전', 7), ('감사', 7), ('행정각부', 7), ('선거관리위원회', 7), ('대법관', 7), ('관리', 7), ('최초', 7), ('평화', 6), ('통일', 6), ('승인', 6), ('누구', 6), ('등', 6), ('청구', 6), ('피고인', 6), ('지체', 6), ('⑥', 6), ('소추', 6), ('재산', 6), ('침해', 6), ('공공', 6), ('재정', 6), ('특별', 6), ('개발', 6), ('회기', 6), ('의장', 6), ('규정', 6), ('이내', 6), ('회계', 6), ('처리', 6), ('규칙', 6), ('자격', 6), ('결정', 6), ('중임', 6), ('제청', 6), ('간', 6), ('당시', 6), ('책임', 5), ('향상', 5), ('운영', 5), ('해산', 5), ('발전', 5), ('제도', 5), ('진술', 5), ('심사', 5), ('이익', 5), ('언론', 5), ('출판', 5), ('내용', 5), ('군인', 5), ('제외', 5), ('기간', 5), ('재의', 5), ('후', 5), ('예산안', 5), ('심의', 5), ('연도', 5), ('개시', 5), ('예산', 5), ('설치', 5), ('계엄', 5), ('계획', 5), ('개정안', 5), ('감사원', 5), ('각급', 5), ('균형', 5), ('이용', 5), ('육성', 5), ('문화', 4), ('영역', 4), ('국군', 4), ('수행', 4), ('체결', 4), ('목적', 4), ('평등', 4), ('검사', 4), ('영장', 4), ('형', 4), ('죄', 4), ('변호인', 4), ('방법', 4), ('범죄', 4), ('비밀', 4), ('타인', 4), ('보상', 4), ('비상계엄', 4), ('선포', 4), ('판결', 4), ('집행', 4), ('근로자', 4), ('조건', 4), ('임시회', 4), ('다음', 4), ('지출', 4), ('부담', 4), ('발의', 4), ('저촉', 4), ('내부', 4), ('규율', 4), ('파면', 4), ('후임자', 4), ('긴급', 4), ('관계', 4), ('원로', 4), ('선고', 4), ('선임', 4), ('농지', 4), ('우리', 3), ('운동', 3), ('조국', 3), ('민족', 3), ('단결', 3), ('자율', 3), ('기회', 3), ('능력', 3), ('균등', 3), ('국제', 3), ('중립', 3), ('일반', 3), ('지위', 3), ('신분', 3), ('활동', 3), ('위배', 3), ('제소', 3), ('인간', 3), ('존엄', 3), ('개인', 3), ('종교', 3), ('영전', 3), ('압수', 3), ('수색', 3), ('처벌', 3), ('현행범', 3), ('증거', 3), ('⑦', 3), ('그', 3), ('입법', 3), ('주거', 3), ('양심', 3), ('결사', 3), ('배상', 3), ('행사', 3), ('문서', 3), ('청원', 3), ('군무원', 3), ('구금', 3), ('외', 3), ('증진', 3), ('단체행동권', 3), ('복지', 3), ('실시', 3), ('사유', 3), ('환경', 3), ('보전', 3), ('기업체', 3), ('계약', 3), ('만료', 3), ('편성', 3), ('변경', 3), ('상호', 3), ('강화', 3), ('선전', 3), ('외국', 3), ('의견', 3), ('해임', 3), ('건의', 3), ('중앙', 3), ('위임', 3), ('대통령령', 3), ('조치', 3), ('해제', 3), ('감형', 3), ('복권', 3), ('대외', 3), ('결산', 3), ('조정', 3), ('지명', 3), ('평화통일', 3), ('원장', 3), ('연임', 3), ('금고', 3), ('여부', 3), ('법령', 3), ('자원', 3), ('농', 3), ('제안', 3), ('불의', 2), ('계승', 2), ('사명', 2), ('입각', 2), ('조화', 2), ('행복', 2), ('주권', 2), ('영토', 2), ('준수', 2), ('의사', 2), ('창달', 2), ('앞', 2), ('차별', 2), ('훈장', 2), ('신체', 2), ('고문', 2), ('자기', 2), ('신청', 2), ('발부', 2), ('제시', 2), ('장기', 2), ('염려', 2), ('조력', 2), ('가족', 2), ('자백', 2), ('유죄', 2), ('처우', 2), ('이전', 2), ('통신', 2), ('허가', 2), ('시설', 2), ('기준', 2), ('명예', 2), ('피해자', 2), ('피해', 2), ('과학', 2), ('공공복리', 2), ('초병', 2), ('초소', 2), ('음식물', 2), ('공급', 2), ('무죄', 2), ('불법', 2), ('손해', 2), ('면제', 2), ('관련', 2), ('구조', 2), ('자주', 2), ('평생', 2), ('포함', 2), ('고용', 2), ('적정', 2), ('임금', 2), ('원칙',  ...

# %%
#  most_common 함수 이용해서 토큰을 빈도가 높은 top five를 구해보세요.
## 실습해보세요
vocab_five = vocab[:5]
print(vocab_five)
# Out:
# [('.', 360), ('법률', 120), ('수', 88), ('대통령', 84), ('조', 78)]

# %% [markdown]
# #### 5-3. mapping string from integer

# %%
# 3. 각 토큰에 정수를 부여하고 dict type의 dictionary를 생성합니다.
dic = {}
i = 0
for (word, frequency) in vocab :
    i +=1 
    dic[word] = i
print("dic :", dic)
# Out:
# dic : {'.': 1, '법률': 2, '수': 3, '대통령': 4, '조': 5, '①': 6, '②': 7, '국가': 8, '헌법': 9, '국민': 10, '국회': 11, '때': 12, '③': 13, '바': 14, '필요': 15, '위원': 16, '기타': 17, '법원': 18, '보장': 19, '국무': 20, '정부': 21, '사항': 22, '이': 23, '회의': 24, '자유': 25, '권리': 26, '선거': 27, '의원': 28, '경제': 29, '④': 30, '국회의원': 31, '의무': 32, '직무': 33, '국무총리': 34, '임명': 35, '조직': 36, '이상': 37, '임기': 38, '의결': 39, '공무원': 40, '경우': 41, '장': 42, '범위': 43, '보호': 44, '법관': 45, '정책': 46, '정당': 47, '재판소': 48, '재적': 49, '항의': 50, '노력': 51, '재판': 52, '인': 53, '요구': 54, '집회': 55, '군사': 56, '시행': 57, '과반수': 58, '출석': 59, '찬성': 60, '자문': 61, '대한민국': 62, '안': 63, '안전': 64, '조약': 65, '심판': 66, '자': 67, '⑤': 68, '중': 69, '처분': 70, '단체': 71, '동의': 72, '탄핵': 73, '권한': 74, '민주': 75, '공포': 76, '기관': 77, '중요': 78, '재판관': 79, '대법원장': 80, '사회': 81, '기본': 82, '정치': 83, '개정': 84, '효력': 85, '체포': 86, '절차': 87, '행위': 88, '교육': 89, '근로': 90, '국정': 91, '명령': 92, '지방': 93, '자치': 94, '질서': 95, '생활': 96, '제정': 97, '투표': 98, '인정': 99, '구속': 100, '형사': 101, '구성': 102, '확정': 103, '제출': 104, '법률안': 105, '항': 106, '행정': 107, '사무': 108, '것': 109, '수립': 110, '유지': 111, '이유': 112, '제한': 113, '공개': 114, '선출': 115, '전': 116, '감사': 117, '행정각부': 118, '선거관리위원회': 119, '대법관': 120, '관리': 121, '최초': 122, '평화': 123, '통일': 124, '승인': 125, '누구': 126, '등': 127, '청구': 128, '피고인': 129, '지체': 130, '⑥': 131, '소추': 132, '재산': 133, '침해': 134, '공공': 135, '재정': 136, '특별': 137, '개발': 138, '회기': 139, '의장': 140, '규정': 141, '이내': 142, '회계': 143, '처리': 144, '규칙': 145, '자격': 146, '결정': 147, '중임': 148, '제청': 149, '간': 150, '당시': 151, '책임': 152, '향상': 153, '운영': 154, '해산': 155, '발전': 156, '제도': 157, '진술': 158, '심사': 159, '이익': 160, '언론': 161, '출판': 162, '내용': 163, '군인': 164, '제외': 165, '기간': 166, '재의': 167, '후': 168, '예산안': 169, '심의': 170, '연도': 171, '개시': 172, '예산': 173, '설치': 174, '계엄': 175, '계획': 176, '개정안': 177, '감사원': 178, '각급': 179, '균형': 180, '이용': 181, '육성': 182, '문화': 183, '영역': 184, '국군': 185, '수행': 186, '체결': 187, '목적': 188, '평등': 189, '검사': 190, '영장': 191, '형': 192, '죄': 193, '변호인': 194, '방법': 195, '범죄': 196, '비밀': 197, '타인': 198, '보상': 199, '비상계엄': 200, '선포': 201, '판결': 202, '집행': 203, '근로자': 204, '조건': 205, '임시회': 206, '다음': 207, '지출': 208, '부담': 209, '발의': 210, '저촉': 211, '내부': 212, '규율': 213, '파면': 214, '후임자': 215, '긴급': 216, '관계': 217, '원로': 218, '선고': 219, '선임': 220, '농지': 221, '우리': 222, '운동': 223, '조국': 224, '민족': 225, '단결': 226, '자율': 227, '기회': 228, '능력': 229, '균등': 230, '국제': 231, '중립': 232, '일반': 233, '지위': 234, '신분': 235, '활동': 236, '위배': 237, '제소': 238, '인간': 239, '존엄': 240, '개인': 241, '종교': 242, '영전': 243, '압수': 244, '수색': 245, '처벌': 246, '현행범': 247, '증거': 248, '⑦': 249, '그': 250, '입법': 251, '주거': 252, '양심': 253, '결사': 254, '배상': 255, '행사': 256, '문서': 257, '청원': 258, '군무원': 259, '구금': 260, '외': 261, '증진': 262, '단체행동권': 263, '복지': 264, '실시': 265, '사유': 266, '환경': 267, '보전': 268, '기업체': 269, '계약': 270, '만료': 271, '편성': 272, '변경': 273, '상호': 274, '강화': 275, '선전': 276, '외국': 277, '의견': 278, '해임': 279, '건의': 280, '중앙': 281, '위임': 282, '대통령령': 283, '조치': 284, '해제': 285, '감형': 286, '복권': 287, '대외': 288, '결산': 289, '조정': 290, '지명': 291, '평화통일': 292, '원장': 293, '연임': 294, '금고': 295, '여부': 296, '법령': 297, '자원': 298, '농': 299, '제안': 300, '불의': 301, '계승': 302, '사명': 303, '입각': 304, '조화': 305, '행복': 306, '주권': 307, '영토': 308, '준수': 309, '의사': 310, '창달': 311, '앞': 312, '차별': 313, '훈장': 314, '신체': 315, '고문': 316, '자기': 317, '신청': 318, '발부': 319, '제시': 320, '장기': 321, '염려': 322, '조력': 323, '가족': 324, '자백': 325, '유죄': 326, '처우': 327, '이전': 328, '통신': 329, '허가': 330, '시설': 331, '기준': 332, '명예': 333, '피해자': 334, '피해': 335, '과학': 336, '공공복리': 337, '초병': 338, '초소': 339, '음식물': 340, '공급': 341, '무죄': 342, '불법': 343, '손해': 344, '면제': 345, '관련': 346, '구조': 347, '자주': 348, '평생': 349, '포함': 350, '고용': 351, '적정': 352, '임금': 353, '원칙': 354, '여자': 355, '단체교섭': 356, '국방': 357, '이행': 358, '보통': 359, '직': 360, '발언': 361, '남용': 362, '취득': 363, '정기회': 364, '인과': 365, '부의장': 366, '이송': 367, '내': 368, '날': 369, '발생': 370, '경비': 371, '계속 ...
